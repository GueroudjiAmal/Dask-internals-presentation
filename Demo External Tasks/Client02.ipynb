# %%
from distributed import Client, Future
from dask import delayed 
import dask.array as da
import numpy as np

# %% [markdown]
# # External Client
#
# ### Hey I have some data for you

# %%
external_client = Client("tcp://127.0.0.1:34227")

# %%
external_client
# Out:
# <Client: 'tcp://127.0.0.1:34227' processes=4 threads=12, memory=31.00 GiB>

# %% [markdown]
# ### Never mind that's not the same client

# %% [markdown]
# ### Wait I don't have the data yet :D

# %%
array = np.random.random((10,10))
array
# Out:
# array([[0.55377916, 0.93949286, 0.78665517, 0.82004144, 0.36198995,
#         0.90990626, 0.06824079, 0.32261925, 0.90970529, 0.43906648],
#        [0.16888606, 0.0143965 , 0.47533159, 0.87162391, 0.62193285,
#         0.15264969, 0.94829281, 0.03987959, 0.10731164, 0.55364956],
#        [0.61250405, 0.45931828, 0.6624148 , 0.16113445, 0.90680385,
#         0.81390387, 0.36034613, 0.6054771 , 0.33639991, 0.20340104],
#        [0.890702  , 0.70083379, 0.14547133, 0.05592733, 0.2895406 ,
#         0.74176435, 0.14757763, 0.0148944 , 0.46161892, 0.3764823 ],
#        [0.27420097, 0.25861404, 0.05135846, 0.5023554 , 0.30634656,
#         0.14042994, 0.53793936, 0.97213544, 0.98837932, 0.20341341],
#        [0.41445851, 0.32794148, 0.55123411, 0.71013744, 0.58312752,
#         0.66725105, 0.48778653, 0.35775078, 0.97388402, 0.88956346],
#        [0.88479646, 0.20099308, 0.59767274, 0.45480281, 0.92531788,
#         0.18572634, 0.43090247, 0.29217084, 0.28995734, 0.13598219],
# ...

# %% [markdown]
# # Sending the data with the expected information
#
# ###  * That's an array of floats
# ###  * Send Directly to the workers (we suppose that we deal with large data)
# ###  * And make sure to activate the `deisa` mode as it will make sure to `update_data` in the scheduler and trigger the transition Algorithm

# %%
deisa_future = external_client.scatter(array, keys=["deisa_key"], deisa=True, direct=True)
deisa_future
# Out:
# <Future: finished, type: numpy.ndarray, key: deisa_key>

# %% [markdown]
# # Go fast and check the computation in the other client :)

# %%
external_client.close()

# %% [markdown]
# # Bye !!
